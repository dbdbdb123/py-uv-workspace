# %%
#!uv add request
#!uv add beautifulssoup4

# %%
import requests
from bs4 import BeautifulSoup

# %%
# https://www.hollys.co.kr/store/korea/korStore2.do

url = "https://www.hollys.co.kr/store/korea/korStore2.do"
res = requests.get(url)
#print(res) # response [200]

#print(res.content) #바이트로 가져옴
#print(res.text) #문자열

soup = BeautifulSoup(res.text,'html.parser')

tag_body = soup.find('tbody')
#print(tag_body)
t_tr = soup.find_all('tr')

# %%
tag_table = soup.select_one('table.tb_store tbody')
tag_tr_list = tag_table.select('tr')

# for tr in tag_tr_list:
#     td_list = tr.find_all('td')
#     print(td_list[0].text)

for tr in tag_tr_list:
    td_list = tr.select('td')

    # --------------------------------------------
    # 매장서비스는 td_list[4] 안에 img alt 값으로 존재
    # 여러 개면 "/" 로 연결해서 저장
    # --------------------------------------------

    service_td = td_list[4] # 매장서비스 칸 
    img_list = service_td.select('img') # 서비스 아이콘

    service_list = []
    for img in img_list:
        alt = img.get('alt')
        if alt :
            service_list.append(alt)
    store_service="/".join(service_list)
    #print(store_service)

    print(  td_list[0].text.strip(),
            td_list[1].text.strip(),
            td_list[2].text.strip(),
            td_list[3].text.strip(),
            store_service,
            td_list[5].text.strip(),)
# Out:
# 충북 음성군 국립소방병원점 영업중 충청북도 음성군 맹동면 용두4길 19 (국립소방병원) /두성리 1531 주차 042-882-0240
# 경기 용인시 수지구 용인수지구청점 영업중 경기도 용인시 수지구 풍덕천로 119 (수지로얄스포츠센타), 109호 . 주차 031-266-3011
# 서울 동작구 이수점 영업중 서울특별시 동작구 동작대로25길 16 (사당동) 1층~2층  02-3478-9029
# 충남 아산시 아산삼성스토어점 영업중 충청남도 아산시 모종로 9-17, 삼성스토어 1층 . 주차 041-543-1233
# 부산 해운대구 부산해운대엘시티점 영업중 부산 해운대구 달맞이길 30,포디움동  2층 2042~2043호 테라스/주차 051-746-3547
# 경기 용인시 기흥구 용인동백점 영업중 경기도 용인시 기흥구 동백중앙로 283 (골드프라자 D동),  203호,204호 주차 .
# 제주 제주시 제주노형점 영업중 제주특별자치도 제주시 노형13길 9 노형동 3791-11 주차 070-8900-1099
# 전남 나주시 나주빛가람혁신도시점 영업중 전라남도 나주시 배멧3길 5-4 . 주차 061-334-5466
# 인천 계양구 아라마루휴게소점 영업중 인천광역시 계양구 아라로 228 (경인아라뱃길아라마루) . 주차 .
# 전북 군산시 (하)군산휴게소점 영업중 전북특별자치도 군산시 성산면 서해안고속도로 141 군산휴게소 하행 1F HOLLYS 주차 .

# %%
result = []
for st in tag_tr_list:

    service_td = td_list[4] # 매장서비스 칸 
    img_list = service_td.select('img') # 서비스 아이콘

    service_list = []
    for img in img_list:
        alt = img.get('alt')
        if alt :
            service_list.append(alt)
    store_service="/".join(service_list)

    td_tel = st.select_one('td:nth-child(6)') # 전화번호

    td_area = st.select_one('td.noline.center_t')    # 지역
    td_point = st.select_one('td:nth-child(2)') # 매장명
    td_open = st.select_one('td:nth-child(3)') # 오픈매장
    td_addr = st.select_one('td:nth-child(4)') # 주소


    result.append([
        td_area.text.strip(),
        td_point.text.strip(),
        td_open.text.strip(),
        td_addr.text.strip(),
        store_service,
        td_tel.text.strip()
    ])

    # print(
    #     td_area.text.strip(),
    #     td_point.text.strip(),
    #     td_open.text.strip(),
    #     td_addr.text.strip(),
    #     store_service,
    #     td_tel.text.strip()
    # )


print(result)

# 파일에 저장
import csv

fields = ['st_area','st_point','st_open','st_addr','store_service','st_tel']
with open("./holly_store_page.csv",'w',encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(fields)
    writer.writerows(result)
# Out:
# [['충북 음성군', '국립소방병원점', '영업중', '충청북도 음성군 맹동면 용두4길 19 (국립소방병원) /두성리 1531', '주차', '042-882-0240'], ['경기 용인시 수지구', '용인수지구청점', '영업중', '경기도 용인시 수지구 풍덕천로 119 (수지로얄스포츠센타), 109호 .', '주차', '031-266-3011'], ['서울 동작구', '이수점', '영업중', '서울특별시 동작구 동작대로25길 16 (사당동) 1층~2층', '주차', '02-3478-9029'], ['충남 아산시', '아산삼성스토어점', '영업중', '충청남도 아산시 모종로 9-17, 삼성스토어 1층 .', '주차', '041-543-1233'], ['부산 해운대구', '부산해운대엘시티점', '영업중', '부산 해운대구 달맞이길 30,포디움동  2층 2042~2043호', '주차', '051-746-3547'], ['경기 용인시 기흥구', '용인동백점', '영업중', '경기도 용인시 기흥구 동백중앙로 283 (골드프라자 D동),  203호,204호', '주차', '.'], ['제주 제주시', '제주노형점', '영업중', '제주특별자치도 제주시 노형13길 9 노형동 3791-11', '주차', '070-8900-1099'], ['전남 나주시', '나주빛가람혁신도시점', '영업중', '전라남도 나주시 배멧3길 5-4 .', '주차', '061-334-5466'], ['인천 계양구', '아라마루휴게소점', '영업중', '인천광역시 계양구 아라로 228 (경인아라뱃길아라마루) .', '주차', '.'], ['전북 군산시', '(하)군산휴게소점', '영업중', '전북특별자치도 군산시 성산면 서해안고속도로 141 군산휴게소 하행 1F HOLLYS', '주차', '.']]

# %%
#파일 읽기
with open("./holly_store_page.csv",'r',encoding="utf-8") as file:
    reader = csv.reader(file)
    for row in reader:
        print(",".join(row))
# Out:
# st_area,st_point,st_open,st_addr,store_service,st_tel
#
# 충북 음성군,국립소방병원점,영업중,충청북도 음성군 맹동면 용두4길 19 (국립소방병원) /두성리 1531,주차,042-882-0240
#
# 경기 용인시 수지구,용인수지구청점,영업중,경기도 용인시 수지구 풍덕천로 119 (수지로얄스포츠센타), 109호 .,주차,031-266-3011
#
# 서울 동작구,이수점,영업중,서울특별시 동작구 동작대로25길 16 (사당동) 1층~2층,주차,02-3478-9029
#
# 충남 아산시,아산삼성스토어점,영업중,충청남도 아산시 모종로 9-17, 삼성스토어 1층 .,주차,041-543-1233
#
# 부산 해운대구,부산해운대엘시티점,영업중,부산 해운대구 달맞이길 30,포디움동  2층 2042~2043호,주차,051-746-3547
#
# 경기 용인시 기흥구,용인동백점,영업중,경기도 용인시 기흥구 동백중앙로 283 (골드프라자 D동),  203호,204호,주차,.
#
# 제주 제주시,제주노형점,영업중,제주특별자치도 제주시 노형13길 9 노형동 3791-11,주차,070-8900-1099
#
# 전남 나주시,나주빛가람혁신도시점,영업중,전라남도 나주시 배멧3길 5-4 .,주차,061-334-5466
#
# 인천 계양구,아라마루휴게소점,영업중,인천광역시 계양구 아라로 228 (경인아라뱃길아라마루) .,주차,.
#
# 전북 군산시,(하)군산휴게소점,영업중,전북특별자치도 군산시 성산면 서해안고속도로 141 군산휴게소 하행 1F HOLLYS,주차,.

# %% [markdown]
# 1.전체 할리스 매장 데이터 크롤링

# %%
# !uv add pandas pytz
# Out:
# Resolved 69 packages in 2ms
# Checked 68 packages in 17ms

# %%
import requests
from bs4 import BeautifulSoup
# import pandas as pd
import time
import datetime
import re
import pytz


BASE_URL = "https://www.hollys.co.kr/store/korea/korStore2.do"




# =====================================================
# 1) pagination 정보 파싱 (페이지번호 + 다음블록 여부)
# =====================================================


def parse_paging_info(soup):
    paging_div = soup.select_one("div.paging")
    if paging_div is None:
            return [],None

    page_numbers = []

    for tag in paging_div.select('a, strong'):
         txt = tag.get_text(strip=True)
         if txt.isdigit():
              page_numbers.append(int(txt))
    next_block_page = None
    for a in paging_div.select('a[onclick]'):
         onclick_text = a.get('onclick')
         match = re.search(r'paging\((\d+)\s*,\s*1\)',onclick_text)
         if match:
              next_block_page = int(match.group(1))
              break

    return page_numbers, next_block_page


# =====================================================
# 2) 총 페이지 수를 블록 이동하면서 끝까지 확인
# =====================================================
def get_total_pages():
    page =1
    max_page =1
    while True:
        print(f"총 페이지 탐색중...({page})")
        params = {'pageNo':page}
        res = requests.get(BASE_URL,params=params)
        soup = BeautifulSoup(res.text,'html.parser')

        page_numbers, next_block_page = parse_paging_info(soup)

        if page_numbers:
            max_page = max(max_page,max(page_numbers))
        
        if next_block_page is None:
            break

        page = next_block_page
        time.sleep(0.2)
    print("최종 페이지 수:",max_page)
    return max_page


# =====================================================
# 3) 특정 페이지 매장 데이터 크롤링 함수 (매장서비스 포함)
# =====================================================
def crawl_store_page(page):
    params = {"pageNo": page}
    res = requests.get(BASE_URL, params=params)


    if res.status_code != 200:
        print(f"{page}페이지 요청 실패:", res.status_code)
        return []


    soup = BeautifulSoup(res.text, "html.parser")


    tbody = soup.select_one("table.tb_store tbody")
    if tbody is None:
        return []


    rows = tbody.select("tr")
    page_result = []


    for row in rows:
        tds = row.select("td")


        # Hollys 테이블은 td 6개 구조임
        if len(tds) < 6:
            continue


        area = tds[0].get_text(strip=True)     # 지역
        name = tds[1].get_text(strip=True)     # 매장명
        status = tds[2].get_text(strip=True)   # 현황
        addr = tds[3].get_text(strip=True)     # 주소


        # 매장서비스는 무조건 5번째 칸 (index=4)
        service_td = tds[4]


        service_list = []
        for img in service_td.select("img"):
            alt = img.get("alt")
            if alt:
                service_list.append(alt.strip())


        store_service = "/".join(service_list)


        phone = tds[5].get_text(strip=True)    # 전화번호


        page_result.append([area, name, status, addr, store_service, phone])


    return page_result



# =====================================================
# 4) 실행부
# =====================================================
if __name__ == "__main__":


    total_pages = get_total_pages()


    all_data = []


    for page in range(1, total_pages + 1):
        print(f"매장 수집중: {page}/{total_pages}")


        page_data = crawl_store_page(page)
        all_data.extend(page_data)


        time.sleep(0.3)
        print(all_data[0])
        break

    #df = pd.DataFrame(all_data, columns=["지역", "매장명", "현황", "주소", "매장서비스", "전화번호"])


    #print("\n최종 매장 수:", len(df))
    #print(df.head())


    #to_now = datetime.datetime.now(pytz.timezone('Asia/Seoul'))
    #to_now = to_now.strftime('%Y-%m-%d %H:%M:%S')


    #filename = '%s-hollys_store_all.csv' % (to_now)
    #filename ='{}-hollys_store.csv'.format(to_now)
    #df.to_csv(filename, index=False, encoding="utf-8")
    #df.to_csv('hollys_store.csv', index=False, encoding="utf-8")
    #print("저장 완료:  hollys_store.csv")
# Out:
# 총 페이지 탐색중...(1)
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[43], line 138
#     134 # =====================================================
#     135 if __name__ == "__main__":
#     136
#     137
# --> 138     total_pages = get_total_pages()
#     139
#     140
#     141     all_data = []
#
# Cell In[43], line 57, in get_total_pages()
#      53
#      54         page_numbers, next_block_page = parse_paging_info(soup)
#      55
#      56         if page_numbers:
# ---> 57             max_page = max(max_page,max(page_numbers))
#      58
#      59         if next_block_page is None:
#      60             break
#
# UnboundLocalError: cannot access local variable 'max_page' where it is not associated with a value
